# %% [markdown]
# # Lambda Treasure Hunt - CS BW2
#
# https://github.com/LambdaSchool/CS-Build-Week-2
# ---
# **Overview**
#
# You start the adventure unworthy, unequipped and anonymous. Your first task is to traverse the island and build a map for your personal use. Along the way, you will discover equipment, treasure and clues which will assist you on your quest for power, wealth and glory.
#
# To efficiently traverse an island maze, collect treasure, solve puzzles, unearth powerful artifacts and more.
#
# Glory and riches await the victors!

# %% [markdown]
# # Build a map

# %% [markdown]
# ## Empty Map

# %%
# graph = {}

# %% [markdown]
# ## Complete Road Map
#
# - 500 rooms
# - Shop: 1 (Sell treasures for gold)
# - Pirate Rye: 467 (Exchange 1000g to change name)
#
# ### After changing name
# - Wishing Well: 55 (Get clue for mining location)
# - Shrines: 22, 374, 461, 491 (Unlock abilities)

# %%
graph = {0: [{'e': 4, 'n': 10, 's': 2, 'w': 1},
  {'cooldown': 1.0,
   'coordinates': '(60,60)',
   'description': 'You are standing in the center of a brightly lit room. You notice a shop to the west and exits to the north, south and east.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': [],
   'players': ['brady - cs24'],
   'room_id': 0,
   'terrain': 'NORMAL',
   'title': 'A brightly lit room'}],
 1: [{'e': 0},
  {'cooldown': 15.0,
   'coordinates': '(59,60)',
   'description': "You are standing in a small shop. A sign behind the mechanical shopkeeper says 'WILL PAY FOR TREASURE'.",
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 1,
   'terrain': 'NORMAL',
   'title': 'Shop'}],
 2: [{'e': 3, 'n': 0, 's': 6},
  {'cooldown': 15.0,
   'coordinates': '(60,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 2,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 3: [{'e': 5, 's': 9, 'w': 2},
  {'cooldown': 20.0,
   'coordinates': '(61,59)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 3,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 4: [{'e': 13, 'n': 23, 'w': 0},
  {'cooldown': 15.0,
   'coordinates': '(61,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 4,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 5: [{'w': 3},
  {'cooldown': 15.0,
   'coordinates': '(62,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 5,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 6: [{'n': 2, 'w': 7},
  {'cooldown': 15.0,
   'coordinates': '(60,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 6,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 7: [{'e': 6, 'n': 8, 'w': 56},
  {'cooldown': 15.0,
   'coordinates': '(59,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 7,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 8: [{'s': 7, 'w': 16},
  {'cooldown': 15.0,
   'coordinates': '(59,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 8,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 9: [{'e': 11, 'n': 3, 's': 12},
  {'cooldown': 20.0,
   'coordinates': '(61,58)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 9,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 10: [{'n': 19, 's': 0, 'w': 43},
  {'cooldown': 15.0,
   'coordinates': '(60,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 10,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 11: [{'e': 17, 'w': 9},
  {'cooldown': 15.0,
   'coordinates': '(62,58)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 11,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 12: [{'e': 14, 'n': 9, 's': 18, 'w': 21},
  {'cooldown': 20.0,
   'coordinates': '(61,57)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 3,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 12,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 13: [{'e': 15, 'w': 4},
  {'cooldown': 15.0,
   'coordinates': '(62,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 13,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 14: [{'e': 37, 's': 34, 'w': 12},
  {'cooldown': 15.0,
   'coordinates': '(62,57)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 14,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 15: [{'w': 13},
  {'cooldown': 15.0,
   'coordinates': '(63,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 15,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 16: [{'e': 8, 'n': 58, 'w': 67},
  {'cooldown': 15.0,
   'coordinates': '(58,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 16,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 17: [{'e': 42, 'n': 24, 'w': 11},
  {'cooldown': 15.0,
   'coordinates': '(63,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 17,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 18: [{'n': 12, 's': 22, 'w': 25},
  {'cooldown': 15.0,
   'coordinates': '(61,56)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 4,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 18,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 19: [{'n': 20, 's': 10, 'w': 77},
  {'cooldown': 15.0,
   'coordinates': '(60,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 19,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 20: [{'e': 27, 'n': 63, 's': 19, 'w': 46},
  {'cooldown': 15.0,
   'coordinates': '(60,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 20,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 21: [{'e': 12, 'w': 29},
  {'cooldown': 15.0,
   'coordinates': '(60,57)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 21,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 22: [{'n': 18, 's': 78, 'w': 36},
  {'cooldown': 20.0,
   'coordinates': '(61,55)',
   'description': 'You are standing at the zenith of Mt. Holloway. You see before you a holy shrine erected in the image of a magnificent winged deity.',
   'elevation': 5,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked east.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 22,
   'terrain': 'MOUNTAIN',
   'title': 'The Peak of Mt. Holloway'}],
 23: [{'e': 26, 's': 4},
  {'cooldown': 15.0,
   'coordinates': '(61,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 23,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 24: [{'s': 17},
  {'cooldown': 15.0,
   'coordinates': '(63,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 24,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 25: [{'e': 18},
  {'cooldown': 1.0,
   'coordinates': '(60,56)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 3,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have flown west.', 'Downhill Flight Bonus: Instant CD'],
   'players': [],
   'room_id': 25,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 26: [{'e': 55, 'w': 23},
  {'cooldown': 15.0,
   'coordinates': '(62,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 26,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 27: [{'e': 30, 'n': 40, 's': 28, 'w': 20},
  {'cooldown': 15.0,
   'coordinates': '(61,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 27,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 28: [{'n': 27},
  {'cooldown': 15.0,
   'coordinates': '(61,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 28,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 29: [{'e': 21, 's': 45, 'w': 49},
  {'cooldown': 15.0,
   'coordinates': '(59,57)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 29,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 30: [{'e': 32, 's': 31, 'w': 27},
  {'cooldown': 15.0,
   'coordinates': '(62,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 30,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 31: [{'e': 33, 'n': 30},
  {'cooldown': 15.0,
   'coordinates': '(62,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 31,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 32: [{'e': 54, 'n': 39, 'w': 30},
  {'cooldown': 15.0,
   'coordinates': '(63,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 32,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 33: [{'e': 38, 'w': 31},
  {'cooldown': 15.0,
   'coordinates': '(63,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 33,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 34: [{'e': 35, 'n': 14, 's': 50},
  {'cooldown': 15.0,
   'coordinates': '(62,56)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 34,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 35: [{'s': 52, 'w': 34},
  {'cooldown': 1.0,
   'coordinates': '(63,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Downhill Flight Bonus: Instant CD'],
   'players': [],
   'room_id': 35,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 36: [{'e': 22, 's': 48, 'w': 60},
  {'cooldown': 20.0,
   'coordinates': '(60,55)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 4,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 36,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 37: [{'w': 14},
  {'cooldown': 15.0,
   'coordinates': '(63,57)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 37,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 38: [{'e': 66, 's': 59, 'w': 33},
  {'cooldown': 15.0,
   'coordinates': '(64,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 38,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 39: [{'e': 51, 'n': 53, 's': 32, 'w': 41},
  {'cooldown': 15.0,
   'coordinates': '(63,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 39,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 40: [{'s': 27},
  {'cooldown': 15.0,
   'coordinates': '(61,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 40,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 41: [{'e': 39},
  {'cooldown': 15.0,
   'coordinates': '(62,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 41,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 42: [{'e': 118, 'n': 44, 's': 80, 'w': 17},
  {'cooldown': 13.5,
   'coordinates': '(64,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 42,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 43: [{'e': 10, 'w': 47},
  {'cooldown': 15.0,
   'coordinates': '(59,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 43,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 44: [{'s': 42},
  {'cooldown': 13.5,
   'coordinates': '(64,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have flown north.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 44,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 45: [{'n': 29, 's': 60},
  {'cooldown': 20.0,
   'coordinates': '(59,56)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 45,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 46: [{'e': 20, 'w': 62},
  {'cooldown': 15.0,
   'coordinates': '(59,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 46,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 47: [{'e': 43, 'n': 71},
  {'cooldown': 15.0,
   'coordinates': '(58,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 47,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 48: [{'n': 36, 's': 105, 'w': 149},
  {'cooldown': 15.0,
   'coordinates': '(60,54)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 3,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 48,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 49: [{'e': 29, 's': 79, 'w': 136},
  {'cooldown': 15.0,
   'coordinates': '(58,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 49,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 50: [{'n': 34, 's': 89},
  {'cooldown': 15.0,
   'coordinates': '(62,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 50,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 51: [{'e': 57, 'n': 69, 'w': 39},
  {'cooldown': 15.0,
   'coordinates': '(64,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 51,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 52: [{'e': 75, 'n': 35, 's': 68},
  {'cooldown': 13.5,
   'coordinates': '(63,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 52,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 53: [{'n': 95, 's': 39, 'w': 88},
  {'cooldown': 15.0,
   'coordinates': '(63,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 53,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 54: [{'w': 32},
  {'cooldown': 15.0,
   'coordinates': '(64,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 54,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 55: [{'w': 26},
  {'cooldown': 15.0,
   'coordinates': '(63,61)',
   'description': "You are standing besides a large well. A sign next the well reads 'EXAMINE WELL, FIND WEALTH'.",
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 55,
   'terrain': 'NORMAL',
   'title': 'Wishing Well'}],
 56: [{'e': 7, 'w': 61},
  {'cooldown': 15.0,
   'coordinates': '(58,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 56,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 57: [{'e': 145, 'w': 51},
  {'cooldown': 15.0,
   'coordinates': '(65,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 57,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 58: [{'s': 16, 'w': 65},
  {'cooldown': 15.0,
   'coordinates': '(58,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 58,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 59: [{'e': 92, 'n': 38, 's': 104},
  {'cooldown': 15.0,
   'coordinates': '(64,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 59,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 60: [{'e': 36, 'n': 45, 'w': 70},
  {'cooldown': 20.0,
   'coordinates': '(59,55)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 3,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 60,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 61: [{'e': 56, 'w': 171},
  {'cooldown': 15.0,
   'coordinates': '(57,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 61,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 62: [{'e': 46, 'n': 64, 'w': 84},
  {'cooldown': 15.0,
   'coordinates': '(58,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 62,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 63: [{'n': 72, 's': 20, 'w': 73},
  {'cooldown': 15.0,
   'coordinates': '(60,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 63,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 64: [{'s': 62, 'w': 82},
  {'cooldown': 15.0,
   'coordinates': '(58,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 64,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 65: [{'e': 58, 'n': 74, 'w': 139},
  {'cooldown': 15.0,
   'coordinates': '(57,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 65,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 66: [{'e': 123, 'n': 169, 'w': 38},
  {'cooldown': 15.0,
   'coordinates': '(65,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 66,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 67: [{'e': 16, 'w': 162},
  {'cooldown': 15.0,
   'coordinates': '(57,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 67,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 68: [{'e': 100, 'n': 52},
  {'cooldown': 13.5,
   'coordinates': '(63,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 68,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 69: [{'e': 103, 'n': 94, 's': 51},
  {'cooldown': 15.0,
   'coordinates': '(64,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 69,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 70: [{'e': 60, 's': 163, 'w': 98},
  {'cooldown': 20.0,
   'coordinates': '(58,55)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 70,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 71: [{'s': 47},
  {'cooldown': 15.0,
   'coordinates': '(58,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 71,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 72: [{'s': 63, 'w': 76},
  {'cooldown': 15.0,
   'coordinates': '(60,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 72,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 73: [{'e': 63},
  {'cooldown': 15.0,
   'coordinates': '(59,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 73,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 74: [{'n': 87, 's': 65, 'w': 161},
  {'cooldown': 15.0,
   'coordinates': '(57,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 74,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 75: [{'e': 85, 'w': 52},
  {'cooldown': 13.5,
   'coordinates': '(64,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 75,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 76: [{'e': 72, 'n': 83, 'w': 110},
  {'cooldown': 15.0,
   'coordinates': '(59,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 76,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 77: [{'e': 19},
  {'cooldown': 15.0,
   'coordinates': '(59,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 77,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 78: [{'n': 22, 's': 108},
  {'cooldown': 15.0,
   'coordinates': '(61,54)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 4,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 78,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 79: [{'n': 49},
  {'cooldown': 15.0,
   'coordinates': '(58,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 79,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 80: [{'e': 86, 'n': 42, 's': 81},
  {'cooldown': 13.5,
   'coordinates': '(64,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 80,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 81: [{'n': 80},
  {'cooldown': 13.5,
   'coordinates': '(64,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 81,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 82: [{'e': 64, 'n': 191},
  {'cooldown': 15.0,
   'coordinates': '(57,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 82,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 83: [{'e': 130, 's': 76, 'w': 125},
  {'cooldown': 15.0,
   'coordinates': '(59,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 83,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 84: [{'e': 62, 'w': 91},
  {'cooldown': 15.0,
   'coordinates': '(57,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 84,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 85: [{'e': 154, 'w': 75},
  {'cooldown': 13.5,
   'coordinates': '(65,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 85,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 86: [{'e': 90, 's': 96, 'w': 80},
  {'cooldown': 13.5,
   'coordinates': '(65,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 86,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 87: [{'s': 74},
  {'cooldown': 15.0,
   'coordinates': '(57,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 87,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 88: [{'e': 53, 'w': 122},
  {'cooldown': 15.0,
   'coordinates': '(62,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 88,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 89: [{'n': 50, 's': 93},
  {'cooldown': 20.0,
   'coordinates': '(62,54)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 89,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 90: [{'e': 178, 'w': 86},
  {'cooldown': 13.5,
   'coordinates': '(66,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 90,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 91: [{'e': 84, 'n': 180, 's': 101, 'w': 99},
  {'cooldown': 15.0,
   'coordinates': '(56,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 91,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 92: [{'w': 59},
  {'cooldown': 15.0,
   'coordinates': '(65,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 92,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 93: [{'n': 89, 'w': 108},
  {'cooldown': 20.0,
   'coordinates': '(62,53)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 93,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 94: [{'n': 152, 's': 69},
  {'cooldown': 15.0,
   'coordinates': '(64,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 94,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 95: [{'n': 119, 's': 53, 'w': 115},
  {'cooldown': 15.0,
   'coordinates': '(63,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 95,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 96: [{'e': 97, 'n': 86},
  {'cooldown': 13.5,
   'coordinates': '(65,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 96,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 97: [{'e': 181, 'w': 96},
  {'cooldown': 13.5,
   'coordinates': '(66,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 97,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 98: [{'e': 70, 'n': 102, 's': 126, 'w': 109},
  {'cooldown': 20.0,
   'coordinates': '(57,55)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 98,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 99: [{'e': 91, 'n': 190, 'w': 146},
  {'cooldown': 15.0,
   'coordinates': '(55,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 99,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 100: [{'e': 112, 's': 106, 'w': 68},
  {'cooldown': 15.0,
   'coordinates': '(64,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 100,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 101: [{'n': 91, 'w': 113},
  {'cooldown': 15.0,
   'coordinates': '(56,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 101,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 102: [{'s': 98, 'w': 142},
  {'cooldown': 15.0,
   'coordinates': '(57,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 102,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 103: [{'n': 160, 'w': 69},
  {'cooldown': 15.0,
   'coordinates': '(65,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 103,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 104: [{'e': 107, 'n': 59},
  {'cooldown': 15.0,
   'coordinates': '(64,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 104,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 105: [{'n': 48, 'w': 202},
  {'cooldown': 15.0,
   'coordinates': '(60,53)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 105,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 106: [{'n': 100, 's': 111, 'w': 135},
  {'cooldown': 15.0,
   'coordinates': '(64,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 106,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 107: [{'e': 121, 's': 120, 'w': 104},
  {'cooldown': 15.0,
   'coordinates': '(65,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 107,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 108: [{'e': 93, 'n': 78, 's': 117},
  {'cooldown': 15.0,
   'coordinates': '(61,53)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 3,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 108,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 109: [{'e': 98, 's': 185, 'w': 175},
  {'cooldown': 15.0,
   'coordinates': '(56,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 109,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 110: [{'e': 76},
  {'cooldown': 15.0,
   'coordinates': '(58,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 110,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 111: [{'e': 158, 'n': 106, 's': 367},
  {'cooldown': 13.5,
   'coordinates': '(64,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 111,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 112: [{'e': 140, 's': 141, 'w': 100},
  {'cooldown': 15.0,
   'coordinates': '(65,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 112,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 113: [{'e': 101, 's': 114},
  {'cooldown': 15.0,
   'coordinates': '(55,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 113,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 114: [{'n': 113, 'w': 176},
  {'cooldown': 15.0,
   'coordinates': '(55,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 114,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 115: [{'e': 95, 'n': 116},
  {'cooldown': 15.0,
   'coordinates': '(62,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 115,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 116: [{'n': 132, 's': 115},
  {'cooldown': 15.0,
   'coordinates': '(62,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 116,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 117: [{'e': 166, 'n': 108, 's': 131, 'w': 133},
  {'cooldown': 15.0,
   'coordinates': '(61,52)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 117,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 118: [{'e': 137, 'w': 42},
  {'cooldown': 13.5,
   'coordinates': '(65,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 118,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 119: [{'n': 134, 's': 95},
  {'cooldown': 15.0,
   'coordinates': '(63,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 119,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 120: [{'e': 127, 'n': 107},
  {'cooldown': 15.0,
   'coordinates': '(65,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 120,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 121: [{'e': 143, 'n': 128, 'w': 107},
  {'cooldown': 15.0,
   'coordinates': '(66,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 121,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 122: [{'e': 88, 'n': 124},
  {'cooldown': 15.0,
   'coordinates': '(61,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 122,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 123: [{'w': 66},
  {'cooldown': 15.0,
   'coordinates': '(66,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 123,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 124: [{'n': 157, 's': 122},
  {'cooldown': 15.0,
   'coordinates': '(61,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 124,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 125: [{'e': 83, 'n': 165, 'w': 237},
  {'cooldown': 15.0,
   'coordinates': '(58,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 125,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 126: [{'n': 98, 's': 129},
  {'cooldown': 15.0,
   'coordinates': '(57,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 126,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 127: [{'e': 184, 'w': 120},
  {'cooldown': 15.0,
   'coordinates': '(66,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 127,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 128: [{'e': 189, 's': 121},
  {'cooldown': 15.0,
   'coordinates': '(66,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 128,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 129: [{'e': 194, 'n': 126, 'w': 170},
  {'cooldown': 15.0,
   'coordinates': '(57,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 129,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 130: [{'w': 83},
  {'cooldown': 15.0,
   'coordinates': '(60,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 130,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 131: [{'n': 117, 's': 244, 'w': 138},
  {'cooldown': 20.0,
   'coordinates': '(61,51)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.', 'Uphill Penalty: 5s CD'],
   'players': [],
   'room_id': 131,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 132: [{'s': 116},
  {'cooldown': 15.0,
   'coordinates': '(62,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 132,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 133: [{'e': 117, 'w': 173},
  {'cooldown': 15.0,
   'coordinates': '(60,52)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 133,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 134: [{'e': 144, 'n': 147, 's': 119},
  {'cooldown': 15.0,
   'coordinates': '(63,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 134,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 135: [{'e': 106, 's': 150},
  {'cooldown': 15.0,
   'coordinates': '(63,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 135,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 136: [{'e': 49, 'w': 148},
  {'cooldown': 15.0,
   'coordinates': '(57,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 136,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 137: [{'w': 118},
  {'cooldown': 13.5,
   'coordinates': '(66,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 137,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 138: [{'e': 131, 's': 211, 'w': 195},
  {'cooldown': 6.75,
   'coordinates': '(60,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown north.',
    'Flight Bonus: -10% CD',
    'Wise Explorer: -50% CD'],
   'players': [],
   'room_id': 138,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 139: [{'e': 65, 'w': 188},
  {'cooldown': 15.0,
   'coordinates': '(56,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 139,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 140: [{'w': 112},
  {'cooldown': 15.0,
   'coordinates': '(66,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 140,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 141: [{'e': 156, 'n': 112},
  {'cooldown': 15.0,
   'coordinates': '(65,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 141,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 142: [{'e': 102, 'w': 159},
  {'cooldown': 15.0,
   'coordinates': '(56,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 142,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 143: [{'e': 212, 'w': 121},
  {'cooldown': 15.0,
   'coordinates': '(67,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 143,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 144: [{'e': 155, 'w': 134},
  {'cooldown': 15.0,
   'coordinates': '(64,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 144,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 145: [{'e': 220, 'n': 174, 'w': 57},
  {'cooldown': 15.0,
   'coordinates': '(66,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 145,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 146: [{'e': 99, 'n': 215, 's': 177, 'w': 257},
  {'cooldown': 15.0,
   'coordinates': '(54,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 146,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 147: [{'e': 153, 'n': 200, 's': 134, 'w': 151},
  {'cooldown': 15.0,
   'coordinates': '(63,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 147,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 148: [{'e': 136, 'w': 292},
  {'cooldown': 15.0,
   'coordinates': '(56,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 148,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 149: [{'e': 48},
  {'cooldown': 15.0,
   'coordinates': '(59,54)',
   'description': 'You are on the side of a steep incline.',
   'elevation': 2,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 149,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 150: [{'n': 135, 'w': 166},
  {'cooldown': 15.0,
   'coordinates': '(63,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 150,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 151: [{'e': 147, 'n': 172, 'w': 207},
  {'cooldown': 15.0,
   'coordinates': '(62,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 151,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 152: [{'s': 94},
  {'cooldown': 15.0,
   'coordinates': '(64,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 152,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 153: [{'e': 329, 'w': 147},
  {'cooldown': 15.0,
   'coordinates': '(64,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 153,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 154: [{'e': 193, 'w': 85},
  {'cooldown': 13.5,
   'coordinates': '(66,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 154,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 155: [{'e': 316, 's': 187, 'w': 144},
  {'cooldown': 15.0,
   'coordinates': '(65,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 155,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 156: [{'e': 164, 's': 168, 'w': 141},
  {'cooldown': 15.0,
   'coordinates': '(66,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 156,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 157: [{'n': 210, 's': 124, 'w': 182},
  {'cooldown': 15.0,
   'coordinates': '(61,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 157,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 158: [{'s': 167, 'w': 111},
  {'cooldown': 13.5,
   'coordinates': '(65,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 158,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 159: [{'e': 142, 'w': 196},
  {'cooldown': 15.0,
   'coordinates': '(55,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 159,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 160: [{'s': 103},
  {'cooldown': 15.0,
   'coordinates': '(65,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 160,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 161: [{'e': 74},
  {'cooldown': 15.0,
   'coordinates': '(56,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 161,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 162: [{'e': 67},
  {'cooldown': 15.0,
   'coordinates': '(56,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 162,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 163: [{'n': 70},
  {'cooldown': 15.0,
   'coordinates': '(58,54)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 163,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 164: [{'e': 298, 'n': 217, 'w': 156},
  {'cooldown': 15.0,
   'coordinates': '(67,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 164,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 165: [{'n': 203, 's': 125, 'w': 204},
  {'cooldown': 15.0,
   'coordinates': '(58,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 165,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 166: [{'e': 150, 's': 198, 'w': 117},
  {'cooldown': 15.0,
   'coordinates': '(62,52)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 166,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 167: [{'e': 260, 'n': 158, 's': 262},
  {'cooldown': 13.5,
   'coordinates': '(65,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 167,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 168: [{'e': 340, 'n': 156},
  {'cooldown': 15.0,
   'coordinates': '(66,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 168,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 169: [{'e': 186, 's': 66},
  {'cooldown': 15.0,
   'coordinates': '(65,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 169,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 170: [{'e': 129},
  {'cooldown': 15.0,
   'coordinates': '(56,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 170,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 171: [{'e': 61},
  {'cooldown': 15.0,
   'coordinates': '(56,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 171,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 172: [{'n': 267, 's': 151},
  {'cooldown': 15.0,
   'coordinates': '(62,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 172,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 173: [{'e': 133, 'w': 214},
  {'cooldown': 15.0,
   'coordinates': '(59,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 173,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 174: [{'e': 224, 'n': 192, 's': 145},
  {'cooldown': 15.0,
   'coordinates': '(66,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 174,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 175: [{'e': 109, 's': 183, 'w': 179},
  {'cooldown': 15.0,
   'coordinates': '(55,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 175,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 176: [{'e': 114, 'w': 402},
  {'cooldown': 15.0,
   'coordinates': '(54,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 176,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 177: [{'n': 146, 'w': 346},
  {'cooldown': 15.0,
   'coordinates': '(54,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 177,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 178: [{'e': 243, 'n': 209, 'w': 90},
  {'cooldown': 13.5,
   'coordinates': '(67,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 178,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 179: [{'e': 175, 's': 233, 'w': 213},
  {'cooldown': 15.0,
   'coordinates': '(54,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 179,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 180: [{'s': 91},
  {'cooldown': 15.0,
   'coordinates': '(56,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 180,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 181: [{'w': 97},
  {'cooldown': 13.5,
   'coordinates': '(67,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 181,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 182: [{'e': 157, 'w': 208},
  {'cooldown': 15.0,
   'coordinates': '(60,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 182,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 183: [{'n': 175, 's': 229},
  {'cooldown': 15.0,
   'coordinates': '(55,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 183,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 184: [{'e': 221, 'w': 127},
  {'cooldown': 15.0,
   'coordinates': '(67,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 184,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 185: [{'n': 109},
  {'cooldown': 15.0,
   'coordinates': '(56,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 185,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 186: [{'e': 205, 'w': 169},
  {'cooldown': 15.0,
   'coordinates': '(66,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 186,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 187: [{'n': 155},
  {'cooldown': 15.0,
   'coordinates': '(65,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 187,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 188: [{'e': 139, 'w': 335},
  {'cooldown': 15.0,
   'coordinates': '(55,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 188,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 189: [{'e': 255, 'w': 128},
  {'cooldown': 15.0,
   'coordinates': '(67,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 189,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 190: [{'s': 99},
  {'cooldown': 15.0,
   'coordinates': '(55,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 190,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 191: [{'s': 82},
  {'cooldown': 15.0,
   'coordinates': '(57,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 191,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 192: [{'e': 223, 'n': 201, 's': 174},
  {'cooldown': 15.0,
   'coordinates': '(66,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 192,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 193: [{'e': 251, 'w': 154},
  {'cooldown': 13.5,
   'coordinates': '(67,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 193,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 194: [{'s': 214, 'w': 129},
  {'cooldown': 15.0,
   'coordinates': '(58,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 194,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   195: [{'s': 228, 'e': 138, 'w': 225},
  {'room_id': 195, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(59,51)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['s', 'e', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
 196: [{'e': 159, 'n': 222, 'w': 197},
  {'cooldown': 15.0,
   'coordinates': '(54,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 196,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 197: [{'e': 196, 'n': 232, 'w': 276},
  {'cooldown': 15.0,
   'coordinates': '(53,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 197,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 198: [{'e': 199, 'n': 166, 's': 239},
  {'cooldown': 15.0,
   'coordinates': '(62,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 198,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 199: [{'s': 230, 'w': 198},
  {'cooldown': 15.0,
   'coordinates': '(63,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 199,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 200: [{'e': 206, 'n': 227, 's': 147},
  {'cooldown': 15.0,
   'coordinates': '(63,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 200,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 201: [{'s': 192},
  {'cooldown': 15.0,
   'coordinates': '(66,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 201,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 202: [{'e': 105},
  {'cooldown': 15.0,
   'coordinates': '(59,53)',
   'description': 'You are at the base of a large, looming mountain.',
   'elevation': 1,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 202,
   'terrain': 'MOUNTAIN',
   'title': 'Mt. Holloway'}],
 203: [{'e': 299, 'n': 268, 's': 165},
  {'cooldown': 15.0,
   'coordinates': '(58,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 203,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 204: [{'e': 165, 'n': 219, 'w': 216},
  {'cooldown': 15.0,
   'coordinates': '(57,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 204,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 205: [{'e': 479, 's': 241, 'w': 186},
  {'cooldown': 15.0,
   'coordinates': '(67,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 205,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 206: [{'e': 380, 'n': 288, 'w': 200},
  {'cooldown': 15.0,
   'coordinates': '(64,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 206,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 207: [{'e': 151, 'n': 231, 'w': 290},
  {'cooldown': 15.0,
   'coordinates': '(61,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 207,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 208: [{'e': 182},
  {'cooldown': 15.0,
   'coordinates': '(59,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 208,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 209: [{'s': 178},
  {'cooldown': 13.5,
   'coordinates': '(67,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have flown north.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 209,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 210: [{'s': 157},
  {'cooldown': 15.0,
   'coordinates': '(61,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 210,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 211: [{'n': 138},
  {'cooldown': 15.0,
   'coordinates': '(60,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 211,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 212: [{'w': 143},
  {'cooldown': 15.0,
   'coordinates': '(68,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 212,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 213: [{'e': 179, 'w': 420},
  {'cooldown': 15.0,
   'coordinates': '(53,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 213,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 214: [{'e': 173, 'n': 194, 'w': 226},
  {'cooldown': 15.0,
   'coordinates': '(58,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 214,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 215: [{'n': 246, 's': 146},
  {'cooldown': 15.0,
   'coordinates': '(54,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 215,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 216: [{'e': 204, 'n': 234, 'w': 218},
  {'cooldown': 15.0,
   'coordinates': '(56,67)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 216,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 217: [{'e': 247, 's': 164},
  {'cooldown': 13.5,
   'coordinates': '(67,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have flown north.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 217,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 218: [{'e': 216, 's': 263, 'w': 242},
  {'cooldown': 15.0,
   'coordinates': '(55,67)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 218,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 219: [{'s': 204},
  {'cooldown': 15.0,
   'coordinates': '(57,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 219,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 220: [{'w': 145},
  {'cooldown': 15.0,
   'coordinates': '(67,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 220,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 221: [{'e': 240, 's': 253, 'w': 184},
  {'cooldown': 15.0,
   'coordinates': '(68,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 221,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 222: [{'n': 305, 's': 196},
  {'cooldown': 15.0,
   'coordinates': '(54,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 222,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 223: [{'n': 283, 'w': 192},
  {'cooldown': 15.0,
   'coordinates': '(67,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 223,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 224: [{'w': 174},
  {'cooldown': 15.0,
   'coordinates': '(67,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 224,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
    225: [{'s': 278,'e': 195},
  {'room_id': 225, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(58,51)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['s', 'e'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
 226: [{'e': 214, 's': 300},
  {'cooldown': 15.0,
   'coordinates': '(57,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 226,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 227: [{'n': 269, 's': 200},
  {'cooldown': 15.0,
   'coordinates': '(63,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 227,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   228: [{'n': 195, 's': 281},
  {'room_id': 228, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(59,50)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's'], 
  'cooldown': 6.75, 'errors': [], 'messages': ['You have flown north.', 'Flight Bonus: -10% CD', 'Wise Explorer: -50% CD']}],
 229: [{'n': 183, 's': 250, 'w': 236},
  {'cooldown': 15.0,
   'coordinates': '(55,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 229,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 230: [{'e': 297, 'n': 199, 's': 307},
  {'cooldown': 15.0,
   'coordinates': '(63,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 230,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 231: [{'s': 207, 'w': 248},
  {'cooldown': 15.0,
   'coordinates': '(61,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 231,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 232: [{'n': 272, 's': 197, 'w': 235},
  {'cooldown': 15.0,
   'coordinates': '(53,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 232,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 233: [{'n': 179, 'w': 238},
  {'cooldown': 15.0,
   'coordinates': '(54,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 233,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 234: [{'n': 368, 's': 216, 'w': 252},
  {'cooldown': 15.0,
   'coordinates': '(56,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 234,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 235: [{'e': 232, 'n': 330, 'w': 355},
  {'cooldown': 15.0,
   'coordinates': '(52,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 235,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 236: [{'e': 229, 's': 264},
  {'cooldown': 15.0,
   'coordinates': '(54,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 236,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 237: [{'e': 125, 'w': 245},
  {'cooldown': 15.0,
   'coordinates': '(57,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 237,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 238: [{'e': 233},
  {'cooldown': 15.0,
   'coordinates': '(53,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 238,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 239: [{'n': 198, 'w': 244},
  {'cooldown': 15.0,
   'coordinates': '(62,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 239,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 240: [{'e': 386, 'n': 249, 'w': 221},
  {'cooldown': 15.0,
   'coordinates': '(69,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 240,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 241: [{'e': 266, 'n': 205},
  {'cooldown': 15.0,
   'coordinates': '(67,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 241,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 242: [{'e': 218, 'n': 287, 's': 259, 'w': 275},
  {'cooldown': 45.0,
   'coordinates': '(54,67)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 242,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 243: [{'e': 256, 's': 293, 'w': 178},
  {'cooldown': 13.5,
   'coordinates': '(68,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 243,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 244: [{'e': 239, 'n': 131},
  {'cooldown': 15.0,
   'coordinates': '(61,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 244,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 245: [{'e': 237, 's': 254},
  {'cooldown': 15.0,
   'coordinates': '(56,66)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 245,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 246: [{'s': 215},
  {'cooldown': 15.0,
   'coordinates': '(54,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 246,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 247: [{'e': 261, 'w': 217},
  {'cooldown': 13.5,
   'coordinates': '(68,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 247,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 248: [{'e': 231, 'n': 296, 'w': 280},
  {'cooldown': 15.0,
   'coordinates': '(60,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 248,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 249: [{'e': 282, 'n': 265, 's': 240},
  {'cooldown': 15.0,
   'coordinates': '(69,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 249,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 250: [{'e': 289, 'n': 229, 's': 294},
  {'cooldown': 15.0,
   'coordinates': '(55,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 250,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 251: [{'e': 315, 'w': 193},
  {'cooldown': 13.5,
   'coordinates': '(68,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 251,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 252: [{'e': 234, 'n': 284},
  {'cooldown': 15.0,
   'coordinates': '(55,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 252,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 253: [{'e': 258, 'n': 221},
  {'cooldown': 15.0,
   'coordinates': '(68,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 253,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 254: [{'n': 245, 'w': 314},
  {'cooldown': 15.0,
   'coordinates': '(56,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 254,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 255: [{'w': 189},
  {'cooldown': 15.0,
   'coordinates': '(68,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 255,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 256: [{'e': 327, 's': 360, 'w': 243},
  {'cooldown': 13.5,
   'coordinates': '(69,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 256,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 257: [{'e': 146, 'n': 320, 'w': 364},
  {'cooldown': 15.0,
   'coordinates': '(53,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 257,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 258: [{'e': 306, 'w': 253},
  {'cooldown': 15.0,
   'coordinates': '(69,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 258,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 259: [{'n': 242, 'w': 310},
  {'cooldown': 15.0,
   'coordinates': '(54,66)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 259,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 260: [{'w': 167},
  {'cooldown': 13.5,
   'coordinates': '(66,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 260,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 261: [{'e': 322, 's': 277, 'w': 247},
  {'cooldown': 13.5,
   'coordinates': '(69,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 261,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 262: [{'e': 358, 'n': 167, 's': 370},
  {'cooldown': 13.5,
   'coordinates': '(65,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 262,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 263: [{'n': 218},
  {'cooldown': 15.0,
   'coordinates': '(55,66)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 263,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 264: [{'n': 236, 's': 274, 'w': 273},
  {'cooldown': 15.0,
   'coordinates': '(54,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 264,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 265: [{'e': 270, 'n': 279, 's': 249},
  {'cooldown': 15.0,
   'coordinates': '(69,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 265,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 266: [{'w': 241},
  {'cooldown': 15.0,
   'coordinates': '(68,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 266,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 267: [{'n': 285, 's': 172, 'w': 271},
  {'cooldown': 15.0,
   'coordinates': '(62,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 267,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 268: [{'e': 411, 's': 203, 'w': 312},
  {'cooldown': 15.0,
   'coordinates': '(58,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 268,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 269: [{'n': 319, 's': 227},
  {'cooldown': 15.0,
   'coordinates': '(63,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 269,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 270: [{'e': 338, 'n': 416, 'w': 265},
  {'cooldown': 15.0,
   'coordinates': '(70,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 270,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 271: [{'e': 267, 'n': 337},
  {'cooldown': 15.0,
   'coordinates': '(61,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 271,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 272: [{'n': 295, 's': 232},
  {'cooldown': 15.0,
   'coordinates': '(53,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 272,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 273: [{'e': 264, 'n': 343},
  {'cooldown': 15.0,
   'coordinates': '(53,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 273,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 274: [{'n': 264, 'w': 308},
  {'cooldown': 15.0,
   'coordinates': '(54,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 274,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 275: [{'e': 242, 'w': 456},
  {'cooldown': 15.0,
   'coordinates': '(53,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You notice a cave entrance to the east and cliffside landmark to the west.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 275,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 276: [{'e': 197, 'w': 419},
  {'cooldown': 15.0,
   'coordinates': '(52,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 276,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 277: [{'e': 323, 'n': 261},
  {'cooldown': 13.5,
   'coordinates': '(69,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 277,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   278: [{'n': 225},
  {'room_id': 278, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(58,50)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 279: [{'s': 265},
  {'cooldown': 15.0,
   'coordinates': '(69,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 279,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 280: [{'e': 248, 'n': 325},
  {'cooldown': 15.0,
   'coordinates': '(59,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 280,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   281: [{'n': 228, 's': 318, 'e': 309, 'w': 317},
  {'room_id': 281, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(59,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's', 'e', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 282: [{'w': 249},
  {'cooldown': 15.0,
   'coordinates': '(70,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 282,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 283: [{'e': 313, 'n': 331, 's': 223},
  {'cooldown': 15.0,
   'coordinates': '(67,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 283,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 284: [{'n': 302, 's': 252, 'w': 303},
  {'cooldown': 15.0,
   'coordinates': '(55,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 284,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 285: [{'n': 286, 's': 267},
  {'cooldown': 15.0,
   'coordinates': '(62,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 285,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 286: [{'n': 336, 's': 285, 'w': 291},
  {'cooldown': 15.0,
   'coordinates': '(62,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 286,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 287: [{'s': 242, 'w': 339},
  {'cooldown': 15.0,
   'coordinates': '(54,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 287,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 288: [{'s': 206},
  {'cooldown': 15.0,
   'coordinates': '(64,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 288,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 289: [{'w': 250},
  {'cooldown': 15.0,
   'coordinates': '(56,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 289,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 290: [{'e': 207},
  {'cooldown': 15.0,
   'coordinates': '(60,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 290,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 291: [{'e': 286, 'n': 410, 'w': 347},
  {'cooldown': 15.0,
   'coordinates': '(61,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 291,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 292: [{'e': 148, 'n': 301},
  {'cooldown': 15.0,
   'coordinates': '(55,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 292,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 293: [{'n': 243},
  {'cooldown': 13.5,
   'coordinates': '(68,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 293,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 294: [{'n': 250, 's': 334},
  {'cooldown': 15.0,
   'coordinates': '(55,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 294,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 295: [{'s': 272},
  {'cooldown': 15.0,
   'coordinates': '(53,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 295,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 296: [{'s': 248},
  {'cooldown': 15.0,
   'coordinates': '(60,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 296,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 297: [{'w': 230},
  {'cooldown': 15.0,
   'coordinates': '(64,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 297,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 298: [{'s': 324, 'w': 164},
  {'cooldown': 15.0,
   'coordinates': '(68,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 298,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 299: [{'e': 311, 'w': 203},
  {'cooldown': 15.0,
   'coordinates': '(59,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 299,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 300: [{'n': 226, 's': 377, 'w': 389},
  {'cooldown': 6.75,
   'coordinates': '(57,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have flown east.',
    'Flight Bonus: -10% CD',
    'Wise Explorer: -50% CD'],
   'players': [],
   'room_id': 300,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 301: [{'n': 304, 's': 292},
  {'cooldown': 15.0,
   'coordinates': '(55,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 301,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 302: [{'n': 422, 's': 284},
  {'cooldown': 45.0,
   'coordinates': '(55,70)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 302,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 303: [{'e': 284, 'n': 361, 'w': 405},
  {'cooldown': 15.0,
   'coordinates': '(54,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 303,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 304: [{'s': 301},
  {'cooldown': 15.0,
   'coordinates': '(55,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 304,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 305: [{'n': 365, 's': 222},
  {'cooldown': 15.0,
   'coordinates': '(54,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 305,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 306: [{'e': 397, 'w': 258},
  {'cooldown': 15.0,
   'coordinates': '(70,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 306,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 307: [{'e': 371, 'n': 230, 's': 373, 'w': 321},
  {'cooldown': 15.0,
   'coordinates': '(63,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 307,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 308: [{'e': 274},
  {'cooldown': 15.0,
   'coordinates': '(53,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 308,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   309: [{'s': 333, 'e': 326,'w': 281},
  {'room_id': 309, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(60,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['s', 'e', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked east.']}],
 310: [{'e': 259, 'w': 412},
  {'cooldown': 15.0,
   'coordinates': '(53,66)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 310,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 311: [{'w': 299},
  {'cooldown': 15.0,
   'coordinates': '(60,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 311,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 312: [{'e': 268, 'n': 328},
  {'cooldown': 15.0,
   'coordinates': '(57,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 312,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 313: [{'w': 283},
  {'cooldown': 15.0,
   'coordinates': '(68,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 313,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 314: [{'e': 254},
  {'cooldown': 15.0,
   'coordinates': '(55,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 314,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 315: [{'w': 251},
  {'cooldown': 13.5,
   'coordinates': '(69,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 315,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 316: [{'n': 344, 'w': 155},
  {'cooldown': 15.0,
   'coordinates': '(66,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 316,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   317: [{'s': 387, 'e': 281, 'w': 409},
  {'room_id': 317, 'title': 'A misty room', 
  'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 
  'coordinates': '(58,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['s', 'e', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
  318: [{'n': 281, 's': 487},
  {'room_id': 318, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(59,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 319: [{'e': 345, 'n': 359, 's': 269},
  {'cooldown': 15.0,
   'coordinates': '(63,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 319,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 320: [{'n': 348, 's': 257},
  {'cooldown': 15.0,
   'coordinates': '(53,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 320,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 321: [{'e': 307, 's': 413},
  {'cooldown': 15.0,
   'coordinates': '(62,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 321,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 322: [{'e': 435, 'n': 382, 'w': 261},
  {'cooldown': 13.5,
   'coordinates': '(70,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 322,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 323: [{'e': 433, 'w': 277},
  {'cooldown': 13.5,
   'coordinates': '(70,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 323,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 324: [{'e': 354, 'n': 298, 's': 349},
  {'cooldown': 15.0,
   'coordinates': '(68,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 324,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 325: [{'n': 353, 's': 280, 'w': 374},
  {'cooldown': 15.0,
   'coordinates': '(59,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 325,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   326: [{'s': 342, 'w': 309},
  {'room_id': 326, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(61,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['s', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked east.']}],
 327: [{'e': 427, 'w': 256},
  {'cooldown': 13.5,
   'coordinates': '(70,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 327,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 328: [{'e': 357, 'n': 332, 's': 312, 'w': 363},
  {'cooldown': 15.0,
   'coordinates': '(57,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 328,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 329: [{'w': 153},
  {'cooldown': 15.0,
   'coordinates': '(65,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 329,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 330: [{'n': 369, 's': 235, 'w': 383},
  {'cooldown': 15.0,
   'coordinates': '(52,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 330,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 331: [{'e': 446, 's': 283},
  {'cooldown': 15.0,
   'coordinates': '(67,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 331,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 332: [{'n': 350, 's': 328},
  {'cooldown': 15.0,
   'coordinates': '(57,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 332,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   333: [{'n': 309, 's': 378},
  {'room_id': 333, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(60,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 334: [{'e': 341, 'n': 294, 's': 393, 'w': 391},
  {'cooldown': 15.0,
   'coordinates': '(55,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 334,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 335: [{'e': 188, 'w': 366},
  {'cooldown': 15.0,
   'coordinates': '(54,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 335,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 336: [{'s': 286},
  {'cooldown': 15.0,
   'coordinates': '(62,74)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 336,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 337: [{'s': 271},
  {'cooldown': 15.0,
   'coordinates': '(61,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [, ],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 337,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 338: [{'s': 379, 'w': 270},
  {'cooldown': 15.0,
   'coordinates': '(71,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 338,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 339: [{'e': 287, 'w': 445},
  {'cooldown': 45.0,
   'coordinates': '(53,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 339,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 340: [{'w': 168},
  {'cooldown': 15.0,
   'coordinates': '(67,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 340,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 341: [{'s': 449, 'w': 334},
  {'cooldown': 15.0,
   'coordinates': '(56,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 341,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   342: [{'n': 326, 's': 342},
  {'room_id': 342, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(61,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 343: [{'s': 273, 'w': 351},
  {'cooldown': 15.0,
   'coordinates': '(53,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 343,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 344: [{'e': 390, 'n': 392, 's': 316},
  {'cooldown': 15.0,
   'coordinates': '(66,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 344,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 345: [{'s': 375, 'w': 319},
  {'cooldown': 15.0,
   'coordinates': '(64,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 345,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 346: [{'e': 177},
  {'cooldown': 15.0,
   'coordinates': '(53,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 346,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 347: [{'e': 291, 'n': 452, 's': 442},
  {'cooldown': 15.0,
   'coordinates': '(60,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 347,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 348: [{'s': 320},
  {'cooldown': 15.0,
   'coordinates': '(53,65)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 348,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 349: [{'e': 384, 'n': 324, 's': 352, 'w': 356},
  {'cooldown': 15.0,
   'coordinates': '(68,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 349,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 350: [{'e': 404, 'n': 436, 's': 332},
  {'cooldown': 15.0,
   'coordinates': '(57,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 350,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 351: [{'e': 343, 's': 491, 'w': 478},
  {'cooldown': 15.0,
   'coordinates': '(52,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 351,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 352: [{'e': 485, 'n': 349, 's': 362},
  {'cooldown': 15.0,
   'coordinates': '(68,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 352,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 353: [{'s': 325},
  {'cooldown': 15.0,
   'coordinates': '(59,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 353,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 354: [{'w': 324},
  {'cooldown': 13.5,
   'coordinates': '(69,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 354,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 355: [{'e': 235},
  {'cooldown': 15.0,
   'coordinates': '(51,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 355,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 356: [{'e': 349},
  {'cooldown': 15.0,
   'coordinates': '(67,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 356,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 357: [{'w': 328},
  {'cooldown': 15.0,
   'coordinates': '(58,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 357,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 358: [{'e': 401, 'w': 262},
  {'cooldown': 13.5,
   'coordinates': '(66,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 358,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 359: [{'s': 319},
  {'cooldown': 15.0,
   'coordinates': '(63,74)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 359,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 360: [{'e': 398, 'n': 256},
  {'cooldown': 13.5,
   'coordinates': '(69,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 360,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 361: [{'n': 408, 's': 303},
  {'cooldown': 45.0,
   'coordinates': '(54,70)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 361,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 362: [{'n': 352, 's': 399, 'w': 463},
  {'cooldown': 15.0,
   'coordinates': '(68,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 362,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 363: [{'e': 328, 'n': 372},
  {'cooldown': 15.0,
   'coordinates': '(56,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 363,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 364: [{'e': 257, 'n': 429, 's': 381, 'w': 448},
  {'cooldown': 15.0,
   'coordinates': '(52,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 364,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 365: [{'s': 305},
  {'cooldown': 15.0,
   'coordinates': '(54,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 365,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 366: [{'e': 335},
  {'cooldown': 15.0,
   'coordinates': '(53,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 366,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 367: [{'n': 111},
  {'cooldown': 13.5,
   'coordinates': '(64,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 367,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 368: [{'s': 234},
  {'cooldown': 15.0,
   'coordinates': '(56,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 368,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 369: [{'n': 400, 's': 330, 'w': 376},
  {'cooldown': 15.0,
   'coordinates': '(52,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 369,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 370: [{'e': 407, 'n': 262, 's': 434},
  {'cooldown': 13.5,
   'coordinates': '(65,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 370,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 371: [{'s': 475, 'w': 307},
  {'cooldown': 15.0,
   'coordinates': '(64,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 371,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 372: [{'n': 441, 's': 363},
  {'cooldown': 15.0,
   'coordinates': '(56,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 372,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 373: [{'n': 307, 's': 480},
  {'cooldown': 15.0,
   'coordinates': '(63,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 373,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 374: [{'e': 325},
  {'cooldown': 15.0,
   'coordinates': '(58,71)',
   'description': 'Here lies a shrine for Full-lifey, who captured the golden snitch and gained the power to warp between worlds with some help from his team and a solitary spy.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 374,
   'terrain': 'NORMAL',
   'title': 'Fully Shrine'}],
 375: [{'e': 385, 'n': 345},
  {'cooldown': 15.0,
   'coordinates': '(64,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 375,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 376: [{'e': 369},
  {'cooldown': 15.0,
   'coordinates': '(51,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 376,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 377: [{'n': 300},
  {'cooldown': 15.0,
   'coordinates': '(57,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 377,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   378: [{'n': 333},
  {'room_id': 378, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(60,47)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 379: [{'e': 395, 'n': 338},
  {'cooldown': 15.0,
   'coordinates': '(71,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 379,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 380: [{'n': 424, 'w': 206},
  {'cooldown': 15.0,
   'coordinates': '(65,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 380,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 381: [{'n': 364, 'w': 394},
  {'cooldown': 15.0,
   'coordinates': '(52,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 381,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 382: [{'e': 388, 's': 322},
  {'cooldown': 13.5,
   'coordinates': '(70,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have flown north.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 382,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 383: [{'e': 330, 'w': 495},
  {'cooldown': 15.0,
   'coordinates': '(51,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 383,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 384: [{'w': 349},
  {'cooldown': 15.0,
   'coordinates': '(69,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 384,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 385: [{'w': 375},
  {'cooldown': 15.0,
   'coordinates': '(65,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 385,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 386: [{'e': 414, 'w': 240},
  {'cooldown': 15.0,
   'coordinates': '(70,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 386,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   387: [{'n': 317, 's': 417, 'w': 431},
  {'room_id': 387, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(58,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 388: [{'e': 477, 'w': 382},
  {'cooldown': 13.5,
   'coordinates': '(71,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 388,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 389: [{'e': 300},
  {'cooldown': 15.0,
   'coordinates': '(56,51)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 389,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 390: [{'w': 344},
  {'cooldown': 15.0,
   'coordinates': '(67,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 390,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 391: [{'e': 334, 's': 396, 'w': 428},
  {'cooldown': 15.0,
   'coordinates': '(54,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 391,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 392: [{'e': 462, 's': 344},
  {'cooldown': 15.0,
   'coordinates': '(66,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 392,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 393: [{'n': 334, 's': 482},
  {'cooldown': 15.0,
   'coordinates': '(55,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 393,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 394: [{'e': 381},
  {'cooldown': 15.0,
   'coordinates': '(51,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 394,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 395: [{'e': 421, 's': 403, 'w': 379},
  {'cooldown': 15.0,
   'coordinates': '(72,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 395,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 396: [{'n': 391},
  {'cooldown': 15.0,
   'coordinates': '(54,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 396,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 397: [{'w': 306},
  {'cooldown': 15.0,
   'coordinates': '(71,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 397,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 398: [{'e': 438, 'w': 360},
  {'cooldown': 13.5,
   'coordinates': '(70,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 398,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 399: [{'n': 362, 's': 467},
  {'cooldown': 15.0,
   'coordinates': '(68,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 399,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 400: [{'s': 369},
  {'cooldown': 15.0,
   'coordinates': '(52,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 400,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 401: [{'w': 358},
  {'cooldown': 13.5,
   'coordinates': '(67,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 401,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 402: [{'e': 176, 'w': 451},
  {'cooldown': 15.0,
   'coordinates': '(53,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 402,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 403: [{'n': 395},
  {'cooldown': 15.0,
   'coordinates': '(72,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 403,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 404: [{'n': 481, 'w': 350},
  {'cooldown': 15.0,
   'coordinates': '(58,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 404,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 405: [{'e': 303, 'n': 406},
  {'cooldown': 15.0,
   'coordinates': '(53,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 405,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 406: [{'s': 405, 'w': 415},
  {'cooldown': 15.0,
   'coordinates': '(53,70)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 406,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 407: [{'s': 496, 'w': 370},
  {'cooldown': 13.5,
   'coordinates': '(66,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 407,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 408: [{'n': 458, 's': 361, 'w': 423},
  {'cooldown': 15.0,
   'coordinates': '(54,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 408,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
   409: [{'e': 317},
  {'room_id': 409, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(57,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['e'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
 410: [{'s': 291},
  {'cooldown': 15.0,
   'coordinates': '(61,74)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 410,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 411: [{'w': 268},
  {'cooldown': 15.0,
   'coordinates': '(59,69)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 411,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 412: [{'e': 310, 's': 488},
  {'cooldown': 15.0,
   'coordinates': '(52,66)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 412,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 413: [{'n': 321},
  {'cooldown': 15.0,
   'coordinates': '(62,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 413,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 414: [{'w': 386},
  {'cooldown': 15.0,
   'coordinates': '(71,59)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 414,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 415: [{'e': 406, 'w': 418},
  {'cooldown': 45.0,
   'coordinates': '(52,70)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 415,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 416: [{'s': 270},
  {'cooldown': 15.0,
   'coordinates': '(70,62)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 416,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   417: [{'n': 387},
  {'room_id': 417, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(58,47)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 418: [{'e': 415, 'n': 425, 's': 474},
  {'cooldown': 15.0,
   'coordinates': '(51,70)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 418,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 419: [{'e': 276},
  {'cooldown': 15.0,
   'coordinates': '(51,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 419,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 420: [{'e': 213, 's': 444, 'w': 437},
  {'cooldown': 15.0,
   'coordinates': '(52,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 420,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 421: [{'n': 440, 'w': 395},
  {'cooldown': 15.0,
   'coordinates': '(73,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 421,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 422: [{'n': 426, 's': 302},
  {'cooldown': 45.0,
   'coordinates': '(55,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 422,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 423: [{'e': 408, 'w': 454},
  {'cooldown': 15.0,
   'coordinates': '(53,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 423,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 424: [{'e': 473, 's': 380},
  {'cooldown': 15.0,
   'coordinates': '(65,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 424,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 425: [{'s': 418, 'w': 469},
  {'cooldown': 15.0,
   'coordinates': '(51,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 425,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 426: [{'n': 457, 's': 422},
  {'cooldown': 45.0,
   'coordinates': '(55,72)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 426,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 427: [{'e': 430, 'w': 327},
  {'cooldown': 13.5,
   'coordinates': '(71,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 427,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 428: [{'e': 391},
  {'cooldown': 15.0,
   'coordinates': '(53,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 428,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 429: [{'s': 364},
  {'cooldown': 15.0,
   'coordinates': '(52,64)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 429,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 430: [{'e': 439, 'n': 443, 'w': 427},
  {'cooldown': 13.5,
   'coordinates': '(72,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 430,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   431: [{'e': 387, 'w': 492},
  {'room_id': 431, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(57,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['e', 'w'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
  432: [{'n': 342},
  {'room_id': 432, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(61,47)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 433: [{'e': 460, 's': 455, 'w': 323},
  {'cooldown': 13.5,
   'coordinates': '(71,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 433,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 434: [{'n': 370},
  {'cooldown': 13.5,
   'coordinates': '(65,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 434,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 435: [{'w': 322},
  {'cooldown': 13.5,
   'coordinates': '(71,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 435,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 436: [{'s': 350},
  {'cooldown': 15.0,
   'coordinates': '(57,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 436,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 437: [{'e': 420, 'w': 497},
  {'cooldown': 15.0,
   'coordinates': '(51,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 437,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 438: [{'e': 465, 'w': 398},
  {'cooldown': 13.5,
   'coordinates': '(71,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 438,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 439: [{'w': 430},
  {'cooldown': 13.5,
   'coordinates': '(73,57)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 439,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 440: [{'s': 421, 'w': 476},
  {'cooldown': 15.0,
   'coordinates': '(73,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 440,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 441: [{'s': 372},
  {'cooldown': 15.0,
   'coordinates': '(56,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 441,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 442: [{'n': 347},
  {'cooldown': 15.0,
   'coordinates': '(60,72)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 442,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 443: [{'e': 471, 's': 430},
  {'cooldown': 13.5,
   'coordinates': '(72,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have flown north.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 443,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 444: [{'n': 420, 'w': 490},
  {'cooldown': 15.0,
   'coordinates': '(52,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'w'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 444,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 445: [{'e': 339, 'n': 447, 'w': 450},
  {'cooldown': 15.0,
   'coordinates': '(52,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 445,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 446: [{'e': 466, 'w': 331},
  {'cooldown': 15.0,
   'coordinates': '(68,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 446,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 447: [{'s': 445},
  {'cooldown': 15.0,
   'coordinates': '(52,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 447,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 448: [{'e': 364},
  {'cooldown': 15.0,
   'coordinates': '(51,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 448,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 449: [{'n': 341},
  {'cooldown': 15.0,
   'coordinates': '(56,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 449,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 450: [{'e': 445},
  {'cooldown': 15.0,
   'coordinates': '(51,68)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 450,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 451: [{'e': 402, 'w': 453},
  {'cooldown': 15.0,
   'coordinates': '(52,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 451,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 452: [{'s': 347},
  {'cooldown': 15.0,
   'coordinates': '(60,74)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 452,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 453: [{'e': 451, 's': 464},
  {'cooldown': 15.0,
   'coordinates': '(51,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 453,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 454: [{'e': 423, 'n': 470},
  {'cooldown': 15.0,
   'coordinates': '(52,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 'e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 454,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 455: [{'n': 433},
  {'cooldown': 13.5,
   'coordinates': '(71,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 455,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 456: [{'e': 275, 'w': 499},
  {'cooldown': 15.0,
   'coordinates': '(52,67)',
   'description': 'You are standing on grass and surrounded by a dense mist. You notice a cave entrance to the east and cliffside landmark to the west.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 456,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 457: [{'n': 461, 's': 426},
  {'cooldown': 45.0,
   'coordinates': '(55,73)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked north.', "It's a trap!: +30s CD"],
   'players': [],
   'room_id': 457,
   'terrain': 'TRAP',
   'title': 'A Dark Cave'}],
 458: [{'s': 408, 'w': 459},
  {'cooldown': 15.0,
   'coordinates': '(54,72)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'w'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 458,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 459: [{'e': 458},
  {'cooldown': 15.0,
   'coordinates': '(53,72)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 459,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 460: [{'w': 433},
  {'cooldown': 13.5,
   'coordinates': '(72,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 460,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 461: [{'s': 457},
  {'cooldown': 15.0,
   'coordinates': '(55,74)',
   'description': 'You are standing before a glowing shrine to a Linh, the Swift. She looks quite fast.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 461,
   'terrain': 'CAVE',
   'title': "Linh's Shrine"}],
 462: [{'w': 392},
  {'cooldown': 15.0,
   'coordinates': '(67,70)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 462,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 463: [{'e': 362, 's': 468},
  {'cooldown': 13.5,
   'coordinates': '(67,49)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e'],
   'items': [],
   'messages': ['You have flown west.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 463,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 464: [{'n': 453},
  {'cooldown': 15.0,
   'coordinates': '(51,60)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 464,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 465: [{'e': 498, 'w': 438},
  {'cooldown': 13.5,
   'coordinates': '(72,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 465,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 466: [{'e': 472, 's': 486, 'w': 446},
  {'cooldown': 15.0,
   'coordinates': '(69,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s', 'e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 466,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 467: [{'n': 399},
  {'cooldown': 15.0,
   'coordinates': '(68,47)',
   'description': "You see a sign before you that reads:\n\n'You have found Pirate Ry's. Send a `change_name` request and I'll change your identity to whatever you wish... for a price.'",
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 467,
   'terrain': 'NORMAL',
   'title': "Pirate Ry's"}],
 468: [{'n': 463},
  {'cooldown': 13.5,
   'coordinates': '(67,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 468,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 469: [{'e': 425},
  {'cooldown': 15.0,
   'coordinates': '(50,71)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 469,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 470: [{'s': 454},
  {'cooldown': 15.0,
   'coordinates': '(52,72)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 470,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 471: [{'w': 443},
  {'cooldown': 13.5,
   'coordinates': '(73,58)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 471,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 472: [{'w': 466},
  {'cooldown': 15.0,
   'coordinates': '(70,68)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 472,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 473: [{'e': 494, 'w': 424},
  {'cooldown': 15.0,
   'coordinates': '(66,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 473,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 474: [{'n': 418},
  {'cooldown': 15.0,
   'coordinates': '(51,69)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 474,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
 475: [{'n': 371, 's': 484},
  {'cooldown': 15.0,
   'coordinates': '(64,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n', 's'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 475,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 476: [{'e': 440},
  {'cooldown': 15.0,
   'coordinates': '(72,61)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 476,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 477: [{'e': 483, 'w': 388},
  {'cooldown': 13.5,
   'coordinates': '(72,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 477,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 478: [{'e': 351},
  {'cooldown': 15.0,
   'coordinates': '(51,53)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 478,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 479: [{'w': 205},
  {'cooldown': 15.0,
   'coordinates': '(68,63)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 479,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 480: [{'n': 373},
  {'cooldown': 15.0,
   'coordinates': '(63,47)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 480,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 481: [{'s': 404},
  {'cooldown': 15.0,
   'coordinates': '(58,73)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['s'],
   'items': [],
   'messages': ['You have walked north.'],
   'players': [],
   'room_id': 481,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 482: [{'n': 393},
  {'cooldown': 15.0,
   'coordinates': '(55,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 482,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 483: [{'w': 477},
  {'cooldown': 13.5,
   'coordinates': '(73,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 483,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 484: [{'n': 475},
  {'cooldown': 15.0,
   'coordinates': '(64,47)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 484,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 485: [{'w': 352},
  {'cooldown': 13.5,
   'coordinates': '(69,50)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 485,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 486: [{'n': 466},
  {'cooldown': 15.0,
   'coordinates': '(69,67)',
   'description': "Before you lies a radiant book of knowledge, on a pedestal inlaid with Lambda Coins. Below, a plaque reads:  Herin exists knowledge gathered by Arron of Web19/CS21. Always seek to learn. Ask questions. Don't panic, bring a towel.",
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 486,
   'terrain': 'NORMAL',
   'title': "Arron's Athenaeum"}],
   487: [{'n': 318,'s': 489},
  {'room_id': 487, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(59,47)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n', 's'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 488: [{'n': 412},
  {'cooldown': 15.0,
   'coordinates': '(52,65)',
   'description': 'You are standing in a dark cave.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 488,
   'terrain': 'CAVE',
   'title': 'A Dark Cave'}],
   489: [{'n': 487},
  {'room_id': 489, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(59,46)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['n'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked south.']}],
 490: [{'e': 444, 'w': 493},
  {'cooldown': 15.0,
   'coordinates': '(51,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e', 'w'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 490,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 491: [{'n': 351},
  {'cooldown': 15.0,
   'coordinates': '(52,52)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have walked south.'],
   'players': [],
   'room_id': 491,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
   492: [{'e': 431},
  {'room_id': 492, 'title': "Sandofsky's Sanctum", 'description': 'Before you stands a statue of Sandofsky, musclebound hero from times of old: Cold as ice and twice as smooth. You feel a chill as thoughts of algorithms fill the air. Before the statue, a plaque reads, "Being a Hero, sometimes you must Recall to Zero."', 'coordinates': '(56,48)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 
  'exits': ['e'], 'cooldown': 15.0, 'errors': [], 'messages': ['You have walked west.']}],
 493: [{'e': 490},
  {'cooldown': 15.0,
   'coordinates': '(50,54)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 493,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 494: [{'w': 473},
  {'cooldown': 15.0,
   'coordinates': '(67,71)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have walked east.'],
   'players': [],
   'room_id': 494,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 495: [{'e': 383},
  {'cooldown': 15.0,
   'coordinates': '(50,58)',
   'description': 'A strange machine stands in this room.  There is a large opening on the top.  A placard reads, "Test your luck!  One item and one Lambdacoin!"',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 495,
   'terrain': 'NORMAL',
   'title': 'The Transmogriphier'}],
 496: [{'n': 407},
  {'cooldown': 13.5,
   'coordinates': '(66,48)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['n'],
   'items': [],
   'messages': ['You have flown south.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 496,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 497: [{'e': 437},
  {'cooldown': 15.0,
   'coordinates': '(50,55)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 497,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 498: [{'w': 465},
  {'cooldown': 13.5,
   'coordinates': '(73,56)',
   'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.',
   'elevation': 0,
   'errors': [],
   'exits': ['w'],
   'items': [],
   'messages': ['You have flown east.', 'Flight Bonus: -10% CD'],
   'players': [],
   'room_id': 498,
   'terrain': 'NORMAL',
   'title': 'A misty room'}],
 499: [{'e': 456},
  {'cooldown': 15.0,
   'coordinates': '(51,67)',
   'description': "You see a moss-topped gravestone which reads: 'Here lies Glasowyn of Web17/Labs12/CS18, who was crushed under the weight of her own gold.' There doesn't seem to be any gold around, but marks in the dirt suggest that someone has knelt there, perhaps in prayer.",
   'elevation': 0,
   'errors': [],
   'exits': ['e'],
   'items': [],
   'messages': ['You have walked west.'],
   'players': [],
   'room_id': 499,
   'terrain': 'NORMAL',
   'title': "Glasowyn's Grave"}]}

# %% [markdown]
# # Initialization

# %%
import json
import time
import random
import requests
# Set up token
token = open('george_token.txt', 'r').read()

# %%
def init(token):
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/init/'
  current = requests.get(url, headers={'Authorization': f'Token {token}'}).json()
  if current['room_id'] not in graph:
    new_room = {}
    for direction in current['exits']:
        new_room[direction] = "?"
    graph[current['room_id']] = [new_room, current]
  return current
current = init(token)
current
# Out:
# {'cooldown': 1.0,
#  'coordinates': '(59,60)',
#  'description': "You are standing in a small shop. A sign behind the mechanical shopkeeper says 'WILL PAY FOR TREASURE'.",
#  'elevation': 0,
#  'errors': [],
#  'exits': ['e'],
#  'items': [],
#  'messages': [],
#  'players': [],
#  'room_id': 1,
#  'terrain': 'NORMAL',
#  'title': 'Shop'}

# %% [markdown]
# # Status, Inventory

# %%
def status_check():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/status/'
  result = requests.post(url, headers={'Content-Type':'application/json',
                                       'Authorization': f'Token {token}'})
  return result.json()
status_check()
# Out:
# {'abilities': ['pray', 'mine', 'fly', 'dash', 'recall'],
#  'bodywear': None,
#  'cooldown': 1.0,
#  'encumbrance': 7,
#  'errors': [],
#  'footwear': None,
#  'gold': 100,
#  'has_mined': False,
#  'inventory': ['tiny treasure',
#   'tiny treasure',
#   'tiny treasure',
#   'tiny treasure',
#   'tiny treasure',
#   'tiny treasure',
#   'tiny treasure'],
#  'messages': [],
#  'name': '[George H]',
#  'speed': 10,
#  'status': [],
#  'strength': 10}

# %% [markdown]
# # Actions
#
# - Movement (move, fly, dash, recall, warp)
# - Treasure (take/sell)
# - Pray (gain abilitie)
# - Mine (Coin)

# %% [markdown]
# ## Movement
#
# - Move, Fly, Dash, Recall, Warp

# %% [markdown]
# ### Breathe First Search
#
# - Finds the shortest path to the destination

# %% [markdown]
# #### Qeue Class

# %%
# Helper class
class Queue():
  def __init__(self):
      self.queue = []
  def enqueue(self, value):
      self.queue.append(value)
  def dequeue(self):
      if self.size() > 0:
          return self.queue.pop(0)
      else:
          return None
  def size(self):
      return len(self.queue)

# %% [markdown]
# #### BFS

# %%
def bfs(starting_room, destination):
  queue = Queue()
  queue.enqueue([starting_room])
  visited = set()
  while queue.size() > 0:
    path = queue.dequeue()
    room_id = path[-1]
    if room_id not in visited:
      if room_id == destination:
        return path
      else:
        for direction in graph[room_id][0]:
          # if graph[room_id][0][direction] != "?":
            new_path = path.copy()
            new_path.append(graph[room_id][0][direction])
            queue.enqueue(new_path)
      visited.add(room_id)
  return []

# %%
# Test
bfs(current['room_id'], 492)
# Out:
# [195, 228, 281, 317, 387, 431, 492]

# %% [markdown]
# ### Move/Fly
#
# - One room traversal
# - Base 15s CD

# %% [markdown]
# #### Basic movement
#
# Move - no buff or penalty
#
# **Wise Explorer Buff**
#
# - Predict the destination room id to reduce CD by 50%
#
#
# ---
#
#
# After obtaining **Fly** ability
#
# Buffs
# - Instant CD when going downhill
# - -10% CD in normal rooms
#
# Penalty
# - +10s CD in CAVE terrains

# %%
# Movement
def movement(direction, next_room_id=None):
  if graph[current['room_id']][1]['terrain'] == 'CAVE':
    url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/move/'
  else:
    # Once you acquire flying ability
    url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/fly/'
  if next_room_id is not None:
    data = f'{{"direction":"{direction}","next_room_id": "{next_room_id}"}}'
    if graph[next_room_id][1]['terrain'] == 'CAVE':
      url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/move/'
  else:
    data = f'{{"direction":"{direction}"}}'
  
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  # Update room_id in graph
  inverse_directions = {"n": "s", "s": "n", "e": "w", "w": "e"}
  if result['room_id'] not in graph:
    graph[result['room_id']] = {}
    for road in result['exits']:
      graph[result['room_id']][road] = "?"
    new_room = {}
    for road in result['exits']:
      new_room[road] = "?"
    graph[result['room_id']] = [new_room, result]
  graph[current['room_id']][0][direction] = result['room_id']
  graph[result['room_id']][0][inverse_directions[direction]] = current['room_id']
  print(result)
  return result

# %%
movement('w',1)
# Out:
# {'room_id': 1, 'title': 'Shop', 'description': "You are standing in a small shop. A sign behind the mechanical shopkeeper says 'WILL PAY FOR TREASURE'.", 'coordinates': '(59,60)', 'elevation': 0, 'terrain': 'NORMAL', 'players': ['User 20508'], 'items': [], 'exits': ['e'], 'cooldown': 6.75, 'errors': [], 'messages': ['You have flown west.', 'Flight Bonus: -10% CD', 'Wise Explorer: -50% CD']}
# {'cooldown': 6.75,
#  'coordinates': '(59,60)',
#  'description': "You are standing in a small shop. A sign behind the mechanical shopkeeper says 'WILL PAY FOR TREASURE'.",
#  'elevation': 0,
#  'errors': [],
#  'exits': ['e'],
#  'items': [],
#  'messages': ['You have flown west.',
#   'Flight Bonus: -10% CD',
#   'Wise Explorer: -50% CD'],
#  'players': ['User 20508'],
#  'room_id': 1,
#  'terrain': 'NORMAL',
#  'title': 'Shop'}

# %% [markdown]
# ### Dash
#
# After obtaining **Dash** ability
# - Cover many rooms in one direction quickly
# - 15s CD + 0.5s CD for each room dashed

# %%
def dash(direction, num_rooms, next_room_ids):
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/dash/'
  next_room_ids = [str(room_id) for room_id in next_room_ids]
  next_room_ids = ','.join(next_room_ids)
  data = f'{{"direction":"{direction}","num_rooms":"{num_rooms}","next_room_id":"{next_room_ids}"}}'
  print(data)
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  print(result)
  return result

# %%
# !curl -X POST -H 'Authorization: Token xxxxxxxxxxxxx' -H "Content-Type: application/json" -d '{"direction":"e", "num_rooms":"3", "next_room_ids":"4,13,15"}' https://lambda-treasure-hunt.herokuapp.com/api/adv/dash/
# Out:
# {"room_id": 15, "title": "A misty room", "description": "You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.", "coordinates": "(63,60)", "elevation": 0, "terrain": "NORMAL", "players": [], "items": [], "exits": ["w"], "cooldown": 16.5, "errors": [], "messages": ["You have dashed to room 4.", "You have dashed to room 13.", "You have dashed to room 15."]}

# %% [markdown]
# ### Recall
#
# - Recall to your starting location Room_id : 0
# - Base 15s CD

# %%
def recall():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/recall/'
  result = requests.post(url, headers={'Content-Type':'application/json',
                                       'Authorization': f'Token {token}'})
  return result.json()
# recall()

# %% [markdown]
# ## Treasure
#
# - Pick up treasures to sell at shop to gain gold
# - Use gold to change name
# - Player can hold up to player's strength stats (10) items
# - When a player's inventory is full: +100% CD

# %%
# Take treasure
def take_item(treasure):
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/take/'
  data = f'{{"name":"{treasure}"}}'
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  if len(result['errors']) > 0:
    print(result['errors'])
  else:
    print(f'Taking {treasure}!')
  return result

# %%
# Sell Treasure
def sell_item(treasure):
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/sell/'
  data = f'{{"name":"{treasure}", "confirm":"yes"}}'
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  print(f'Selling {treasure} to shop.\n{result}')
  return result

# %% [markdown]
# ### Manual selling treasures

# %%
time.sleep(current['cooldown'])
items = status_check()['inventory']
for item in items:
  if 'treasure' in item:
    current = sell_item(item)
    time.sleep(current['cooldown'])

# %% [markdown]
# ## Name Change
#
# Room 467 - Use 1000g to change name to unlock abilities and pray

# %%
def name_change(new_name):
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/change_name/'
  data = f'{{"name":"{new_name}", "confirm":"aye"}}'
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  print(f'Changing name to {new_name}!')
  return result
# name_change('Jon Doe')

# %% [markdown]
# ## Pray at Shrine
#
# Need to change name first to pray and unlock abilities
# - 22 - Fly: Good for all terrains except cave.
# - 374 - Warp: Must be have both bodywear and footwear equipped to warp.
# - 461 - Dash: Cover many rooms in one direction quickly
# - 492 - Recall: Recall to starting Room[0]

# %%
def pray():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/pray/'
  result = requests.post(url, headers={'Content-Type':'application/json',
                                       'Authorization': f'Token {token}'})
  return result.json()
# pray()

# %% [markdown]
# # Lambda Coin

# %% [markdown]
# ## Examine Well for clue
#
# - Room 55
# - Decipher clue to get mining room location

# %%
def wishing_well():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/adv/examine/'
  data = f'{{"name":"{Well}"}}'
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  print(result['description'])
  return result
# wishing_well()

# %% [markdown]
# ## Mining Coin

# %%
def mine_coin():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/bc/mine/'
  data = f'{{"proof":{new_proof}}}'
  result = requests.post(url, data=data,
                         headers={'Content-Type':'application/json',
                                  'Authorization': f'Token {token}'}).json()
  return result

# %%
def last_proof():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/bc/last_proof/'
  result = requests.get(url, 
                        headers={'Content-Type':'application/json',
                                 'Authorization': f'Token {token}'}).json()
  return result

# %% [markdown]
# ## Check Coin Balance

# %%
def coin_balance():
  url = 'https://lambda-treasure-hunt.herokuapp.com/api/bc/get_balance/'
  result = requests.get(url, 
                        headers={'Content-Type':'application/json',
                                 'Authorization': f'Token {token}'}).json()
  return result["messages"]
coin_balance()
# Out:
# ['You have a balance of 0 Lambda Coins']

# %% [markdown]
# # Traversal

# %%
inverse_directions = {"n": "s", "s": "n", "e": "w", "w": "e"}
# prev_move = None
while True:
  current_exits = graph[current['room_id']][0]
  # directions = []
  # for direction, room_id in current_exits.items():
  #   # If adjacent room_id not visited yet, add that direction
  #   if room_id == "?":
  #     directions.append(direction)
  # if len(directions) == 0:
    # print('All adjacent rooms visited..')
  targets = bfs(current['room_id'], 1)[1:]
  for direction, room_id in current_exits.items():
    if room_id == targets[0]:
      # Figure out the direction of next room
      next_move = direction
      break
  # Dashing..
  # next_room_ids = [targets[0]]
  # for index in range(len(targets)):
  #   if graph[targets[index]][0][next_move] == targets[index+1]:
  #     next_room_ids.append(targets[index+1])
  #   else:
  #     break
  # else:
  #   next_move = random.choice(directions)
  # if len(next_room_ids) > 1:
  #   print(f'Dashing.. {next_move} to {next_room_ids}')
  #   end_room = dash(next_move, len(next_room_ids), next_room_ids)
  # else:
  print(f'Room[{current["room_id"]}] to Room[{current_exits[next_move]}]')
  if current_exits[next_move] == "?":
    print(f"Traveling to the unknown.. ({len(graph)}/500)")
    end_room = movement(next_move)
  else:
    # Use "Wise Explorer" buff
    end_room = movement(next_move, current_exits[next_move])
  print(f"CD: {end_room['cooldown']}, {end_room['messages']}")
  # if len(end_room['items']) > 0:
  #   for item in end_room['items']:
  #     if 'treasure' not in item:
  #       print(f'{item} found in {end_room["room_id"]}')
  #       time.sleep(end_room['cooldown'])
  #       end_room = take_item(item)
  # if end_room['title'] == 'Shop':
  #   time.sleep(end_room['cooldown'])
  #   items = status_check()['inventory']
  #   for item in items:
  #     if 'treasure' in item:
  #       time.sleep(end_room['cooldown'])
  #       end_room = sell_item(item)
  # prev_move = next_move
  if len(end_room['errors']) > 0:
    print(f"Error: {end_room['errors']}")
    break
  current = end_room
  time.sleep(current['cooldown'])
# Out:
# Room[195] to Room[228]
# {'room_id': 228, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(59,50)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 'exits': ['n', 's'], 'cooldown': 6.75, 'errors': [], 'messages': ['You have flown south.', 'Flight Bonus: -10% CD', 'Wise Explorer: -50% CD']}
# CD: 6.75, ['You have flown south.', 'Flight Bonus: -10% CD', 'Wise Explorer: -50% CD']
# Room[228] to Room[281]
# {'room_id': 281, 'title': 'A misty room', 'description': 'You are standing on grass and surrounded by a dense mist. You can barely make out the exits in any direction.', 'coordinates': '(59,49)', 'elevation': 0, 'terrain': 'NORMAL', 'players': [], 'items': [], 'exits': ['n', 's', 'e', 'w'], 'cooldown': 6.75, 'errors': [], 'messages': ['You have flown south.', 'Flight Bonus: -10% CD', 'Wise Explorer: -50% CD']}
# ...
